# %% [markdown]
# # potato

# %%
# This Python file is here to help you get started applying NLTK to your own text files. 
# So it's going to read in a file from your own directwory and tokenize it so NLTK can analyze it. 
import nltk
import matplotlib
import matplotlib.pyplot as plt
# Here we're going to open a file stored in the same folder with this Python script. 
# We'll open it in a block: and everything that happens inside the block stays in the block: 
# The file is ONLY open inside this block, so we'll write all the NLP processing of it inside, indented within it:
with open("avatarSpeeches.txt", 'r', encoding='utf-8') as file:
    text=file.read() #ebb: This unpacks the text from the file
    textTokens=text.split() #ebb: This will chop up the text on its spaces and around punctuation marks and give you a list of them.
    # Uncomment the line below to see a sorted set of unique words in your text:
    # print(sorted(set((textTokens)))[:20])
    
    # You don't have to do this, but here's a little "list comprehension" to lowercase each token in the list:
    lowerCaseTokens = [w.lower() for w in textTokens]
    # What if you change this to uppercase the tokens? 
    print(set(lowerCaseTokens))

    # You've created a list of tokens with textTokens
    # Now, we have to turn these tokens into an NLTK Text Object for the NLTK library to work with:
    avatarTextObject = nltk.Text(lowerCaseTokens)
    # Here we create a text object out of any list of tokens. (this could be the orignal textTokens.)

    # This nifty syntax below is called an "f-string" and it lets you label the thing you're outputting so you know what it is:
    print(f"Avatar as NLTK Text Object = {avatarTextObject}")
    # So you have a Text Object which puts your list of tokens in a fancy wrapper for NLTK to work with. (You can treat this file just like one of the NLTK book donwloads now.)
    # Try NLTK stuff now, like making a concordance or a disperson plot. 
    print("How many avatar:", avatarTextObject.count("avatar"))
    
    avatarTextObject.dispersion_plot(["run", "ran", "fly", "flying", "flew"])
    plt.show()
    # Lots of tokens have punctuation and lots of word forms. Stemming would help find and track the root words. Read more about it in the NLTK book.
# Out:
# {'word', 'badgermoles;', 'full,', 'yeah,', 'face!', 'rich', 'half', 'doing!?', 'envy', 'tents!', 'return.', 'hourly', 'passports', 'li.', 'mistakes.', 'yet?', 'unusual', 'hours.', 'straightening', 'tonight.', 'catching', 'vanity', 'tea.', 'awkward', 'lockdown!', 'yourself.', 'lord."', 'assortment-', 'vision,', 'sand,', 'penguin', 'leaf', 'hope.', 'tour', 'ago.', 'kissed', 'flamin\'".', 'vouch.', 'hahaha!', 'airbender!', 'space.', 'personally!', 'die?', 'born,', 'ears!', 'burdened', 'my,', 'why!', 'blast', 'things.', 'collapsed', 'bow', 'returns', 'veggies', "where'd", 'direction', 'kiss', 'talks', 'humans?', 'boat!', "name's", 'thanks', 'drill!', 'volunteers', 'bind', 'wound', 'robbers,', 'evade.', 'wrong', 'mountain?', 'burning', 'blanket', 'allies.', 'refurbishing,', 'honor.', 'careful.', 'pasty,', 'woman,', 'boys', 'school,', 'kept', 'empty,', 'breakfast.', 'problems', 'critters', 'studied', 'which', 'drink', 'luck,', 'legacy,', 'winds,', 'polluting', 'ordinary', 'does-', 'pants?', 'push.', 'mongke', 'frankly,', 'off!', 'sleeve', 'leaving?', 'disgrace.', 'dares', 'rha.', 'unkind', 'art', 'cabbages.', 'wait?', 'accidentally', 'dear.', 'remainder', 'mai?', 'waterbender,', 'complain,', 'moons!', 'terra', 'connive,', "should've", 'brother', 'scam', 'beloved', 'highest', 'abuse', "teo's", 'suit!', "appa's", 'neither', 'doors', 'valley.', 'it,', 'chō', 'innocence?', 'slim.', 'yet', 'cliffs', 'ridiculous,', 'vase?', 'stop', 'nicer', 'kidding,', 'oval', 'kumquats.', 'disappeared', 'ointments', 'time?', 'fifth', 'faces', '"okay"', 'quickly.', 'accident!', 'place?', 'training!', 'skin?', 'traditions!', '"boiled', 'ozai.', 'run', 'impressive,', 'levitates', 'messy,', 'scroll.', 'clothes', 'mmmm!', 'aware', 'fur.', 'humanity', 'death!', 'insisted', 'disrespect,', 'buster.', 'gran', 'hold!', 'countdown', 'custody.', 'jangle', 'regain', 'peninsula', 'defense.', 'forty-first', 'tea?', 'cough.', 'eye', 'schedule,', 'un-fried', 'desert.', 'helpful?', 'mind?', 'relax!', 'son-in-law.', 'hearts.', 'penguins?', 'explode.', 'wish', 'crawling', 'gondolas!', 'hippo', 'searching', 'softest', 'terrain', 'shot?', 'not,', 'twins', 'ba', 'pouty.', "sozin's", 'rivers', 'nothing!', 'tricking', 'below', 'throughout', 'omashu,', 'to,', 'possum', 'warm!', 'died,', 'emerged', 'banish', '"toph', 'asked', 'along!', 'explanation.', 'stronger?', 'excellent', 'clear!', 'disappointments', 'wonderful,', 'eternal', 'heart!', 'worrywart', 'wake', 'quitter!', 'number', 'yeah\u200c?', 'knew', 'becomes', 'pippinpaddleopsicopolis?', 'deemed', 'class', 'acupuncture!', 'gifted!', 'project.', 'days:', 'huge!', 'mm-mm.', 'startled', 'wise', 'babies', 'canyon?', 'bravery', 'unannounced?', 'begins', 'screaming.', 'regret,', 'ozai?', 'strongest', 'funny?', 'secret', 'junior.', 'drain.', 'pushed', 'suffered,', 'stomach!', 'dee.', 'malicious', "friend's", 'yes,', 'prop.', 'sang', 'rigid', 'fishing.', 'curd', 'collection.', 'girlfriend.', 'fighting,', 'yip-yip!', 'priority', 'shush', 'potty', 'mess,', 'bridge!', 'maiden!', 'perky.', 'basics.', 'apple', 'tired', 'around,', 'hold,', 'spy', 'jobs?', 'chamber,', 'thee!', 'alert,', "dragons'", 'forth?', 'wisely.', 'fella,', 'freedom,', 'escape!', "jeong's", 'drink?', 'peace.', 'star', 'traveling.', 'gliding.', 'fugitives!', 'smoothly', 'ow', 'subjects.', 'unagi', 'invasion!', 'require', 'handsome?', 'poster.', 'manage!', 'destined', 'around.', 'focusing', 'buzzing', 'vision', 'chameleon', 'grass', 'aye,', 'boo', 'komodo', 'direction.', 'swear', 'for.', 'heated', 'discovered', 'care?', 'ventilated.', 'fellas', 'cast', 'father,', 'arrives,', 'zig-zags!', 'orders?', 'felt', 'apart!', 'home,', 'resistance', 'downfall,', 'rendezvous', 'saddle?', 'field.', 'surprise,', 'question?', 'marked', 'airbending.', 'colorful,', 'chanters!', 'city', 'elements.', 'accomplishment:', 'calm!', 'north', 'well,', 'campfire?', 'congratulations.', 'aang:', 'same.', 'look.', 'tasty.', 'begged', 'cracks', 'though,', 'rooting', 'crystals.', 'family', 'years,', ' ...
# Avatar as NLTK Text Object = <Text: no! stop sinking! don't make me put this...>
# How many avatar: 216

# %%
import nltk
import matplotlib
import matplotlib.pyplot as plt
from nltk.probability import FreqDist

with open("avatarSpeeches.txt", 'r', encoding='utf-8') as file:
    textRaw = file.read()
    tokens = textRaw.split()
    
    tokens = [w.lower() for w in tokens]

    textObj = nltk.Text(tokens)

    # Most common words:
    dist = FreqDist(tokens)
    print("10 most common words:", dist.most_common(10))

    # Length of text
    entire = len(textObj)
    print("Combined text length:", entire)

    # Words in similar contexts as avatar
    print("Words in similar contexts as 'avatar':")
    textObj.similar("avatar")

    # Plot
    words = ["aang", "sokka", "zuko", "katara", "toph"]
    nltk.draw.dispersion_plot(textObj, words)
# Out:
# 10 most common words: [('the', 4080), ('you', 3406), ('i', 3252), ('to', 2998), ('a', 2052), ('and', 1605), ('of', 1364), ('is', 1095), ('we', 1014), ('it', 920)]
# Combined text length: 110464
# Words in similar contexts as 'avatar':
# fire and i what you but water earth spirit the not world war one if so
# way same north right
