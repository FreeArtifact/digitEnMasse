# %% [markdown]
# # potato

# %%
# This Python file is here to help you get started applying NLTK to your own text files. 
# So it's going to read in a file from your own directwory and tokenize it so NLTK can analyze it. 
import nltk
import matplotlib
import matplotlib.pyplot as plt
# Here we're going to open a file stored in the same folder with this Python script. 
# We'll open it in a block: and everything that happens inside the block stays in the block: 
# The file is ONLY open inside this block, so we'll write all the NLP processing of it inside, indented within it:
with open("avatarSpeeches.txt", 'r', encoding='utf-8') as file:
    text=file.read() #ebb: This unpacks the text from the file
    textTokens=text.split() #ebb: This will chop up the text on its spaces and around punctuation marks and give you a list of them.
    # Uncomment the line below to see a sorted set of unique words in your text:
    # print(sorted(set((textTokens)))[:20])
    
    # You don't have to do this, but here's a little "list comprehension" to lowercase each token in the list:
    lowerCaseTokens = [w.lower() for w in textTokens]
    # What if you change this to uppercase the tokens? 
    print(set(lowerCaseTokens))

    # You've created a list of tokens with textTokens
    # Now, we have to turn these tokens into an NLTK Text Object for the NLTK library to work with:
    avatarTextObject = nltk.Text(lowerCaseTokens)
    # Here we create a text object out of any list of tokens. (this could be the orignal textTokens.)

    # This nifty syntax below is called an "f-string" and it lets you label the thing you're outputting so you know what it is:
    print(f"Avatar as NLTK Text Object = {avatarTextObject}")
    # So you have a Text Object which puts your list of tokens in a fancy wrapper for NLTK to work with. (You can treat this file just like one of the NLTK book donwloads now.)
    # Try NLTK stuff now, like making a concordance or a disperson plot. 
    print("How many avatar:", avatarTextObject.count("avatar"))
    
    avatarTextObject.dispersion_plot(["run", "ran", "fly", "flying", "flew"])
    plt.show()
    # Lots of tokens have punctuation and lots of word forms. Stemming would help find and track the root words. Read more about it in the NLTK book.
# Out:
# {'metal', 'reasonable', 'herds', 'search', 'xu', 'weekend.', '"no', 'creates', 'first?', 'patient', 'reveals', 'smoothing', 'nutcracker.', 'infuriating!', 'nicer', 'crawler!', 'done!', 'timid,', 'parts.', 'rule.', 'annoying', 'devastation', 'cabbages', 'compartment', 'activity?', 'mistakes.', 'fun!', 'blasting', 'frozen', 'call,', 'pretending', 'enormous!', 'fliers', 'strong', 'incredibly', 'execution.', 'impressive,', 'handsome?', 'pick?', 'tall!', 'branch', 'knew?', 'second', 'opportunity,', 'ball!', 'words-', 'confront', 'fault.', 'tribe!', 'suggesting', 'dirt.', 'leave?', 'prisoners!', 'robe!', 'killer,', 'missions', 'slug', 'continent', 'pit', 'hold,', 'carefully,', 'downhill', 'larger,', "iroh's", 'below!', 'hawky,', 'rat', 'invisible', 'baby,', 'should', 'carefully.', 'expert.', 'mugging', 'away.', 'sooner,', 'given', 'eh,', 'left,', 'pentapox!', 'aang!', 'direction.', 'was', 'enemies', 'training,', 'aaahhh!', 'excited,', 'monks?', 'gunking', 'unlocked', 'elaborate', 'capturing', 'dance!', 'plotting', 'rhymes', 'creativity,', 'attention,', 'ahhh,', '"penetrable', 'anywhere', 'practice.', 'major.', 'myself', 'yelled', 'whip!', 'juggler', 'mission', 'injured.', 'dress', 'june!', 'words.', 'yard', 'uncivilized', 'professor,', 'balloons.', 'knife.', 'servants.', 'boo-hoo,', 'school-', 'too,', 'chew', 'cycle', 'courtesy', 'ever.', 'possible?', 'stranger', 'occurred.', 'cook', 'trimmed', 'flashes.', 'paper,', 'everything,', 'envy', '"foxy"', 'superstition!', 'bag?', 'interested,', 'huh,', 'flatter', 'top', 'got!', 'ourselves.', 'scam?', 'frankly,', 'first,', 'restraint.', 'arrested,', 'massive', 'needs.', 'comfort', 'jinju', '"not', 'gang?', 'ha.', 'goody-goody.', 'trap–', 'fall,', 'ordered', 'foot', 'guide', 'fabulous!', 'dear.', 'bing-bang-boom,', 'lieutenant', 'placed', 'snack', 'kingdom', 'infirmary,', 'false', 'twins!', 'trait.', 'suggesting,', 'ink', 'borrow', 'rooted.', 'apologizing', 'conqueror,', 'slug.', 'report', 'sell', 'do?', 'hang', 'recover', 'price.', 'environment', 'talking!', 'wrong', 'flopsie,', 'statues?', 'man?', 'nope,', 'leads,', 'cliff.', 'suffering.', 'level.', 'se:', 'great!', 'jing', 'brave,', 'likes.', 'yet,', 'sons', 'vi.', 'ignorant.', 'files?', 'boats', 'pot!', 'dock,', 'hopefully', 'stuffy,', 'witch?', 'predictions.', 'skills.', 'fong,', 'scorch', '"zuko".', 'weaknesses', 'she.', 'teach', 'aw!', 'unload?', 'any.', 'd-did', 'assure', 'era', 'system?', 'shy,', 'jammed', 'appa!', 'replace', 'needa', 'previously', 'tailbone.', 'ship,', 'mile', 'underwater?', 'sandy', 'hole!', 'mountains', 'together?', 'orb,', 'gift', 'respected', 'land', 'realized', 'boat!', 'has', 'ancient', 'break?', 'river.', 'about,', 'net', 'drill!', 'firelight', 'sure:', 'seem!', 'themselves', '"both"?!', 'hurt.', 'hat', 'banished', 'apparently', 'bend', 'injury', 'universe\u200c?', 'forever!', 'intoxicating.', 'shade!', 'suit', 'package-sending', 'scarcely', 'looks,', 'naturally', 'ugh!', 'crystal.', 'boom!', 'ways.', 'ooh.', 'raise.', 'suki.', 'tim,', 'was,', 'valley.', 'killed!', 'campfires,', 'explosives', 'true?', 'ours.', 'stars', 'ever!', 'travelers', 'soldiers', 'wrong,', 'guide,', 'exploding', '"freakish",', 'yourself!', 'rise', 'yip,', "she's", 'disappearing', 'cure!', 'trash?', 'stands', 'first!', 'lily.', '"stay', 'tree', 'remove', 'balloon?', 'objective', 'gut', 'slurry,', 'science', 'tho.', 'test.', 'questions.', 'life.', 'lord."', 'lion.', 'humanity', 'dragons.', 'my', 'what?', 'misses', 'buried.', "you'll", 'feel', 'second!', 'cheated.', 'properties.', 'sounds!', 'met.', 'just–', 'passed,', 'new.', 'weaving', 'quarters', 'deed,', 'stowaways', "i'm", 'morning.', 'papaya!', 'trees.', 'us,', 'keys!', 'hornist.', 'supports', 'fate!', 'canyon', 'train', 'afford', 'times,', 'underneath', 'wart', 'pathway', 'moved', 'anyone', 'ya!', 'am!', 'used', 'mango', 'resistance!', 'this,', 'breakfast.', 'hahaha,', 'meaning', 'move', 'out.', 'party?', 'pleased.', 'boys.', 'take?', "here's", 'hairy', 'no!', "bandit's", 'what?!', ...
# Avatar as NLTK Text Object = <Text: no! stop sinking! don't make me put this...>
# How many avatar words: 216

# %%
import nltk
import matplotlib
import matplotlib.pyplot as plt
from nltk.probability import FreqDist

with open("avatarSpeeches.txt", 'r', encoding='utf-8') as file:
    textRaw = file.read()
    tokens = textRaw.split()
    
    tokens = [w.lower() for w in tokens]

    textObj = nltk.Text(tokens)

    # Most common words:
    dist = FreqDist(tokens)
    print("10 most common words:", dist.most_common(10))

    # Length of text
    entire = len(textObj)
    print("Combined text length:", entire)

    # Words in similar contexts as avatar
    print("Words in similar contexts as 'avatar':")
    textObj.similar("avatar")
# Out:
# 10 most common words: [('the', 4080), ('you', 3406), ('i', 3252), ('to', 2998), ('a', 2052), ('and', 1605), ('of', 1364), ('is', 1095), ('we', 1014), ('it', 920)]
# Combined text length: 110464
# Words in similar contexts as 'avatar':
# fire and i what you but water earth spirit the not world war one if so
# way same north right
